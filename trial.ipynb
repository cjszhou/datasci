# %% [markdown]
# SIN func

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn-dark')

# %%
x=np.arange(0,2*np.pi,0.01)
y=np.sin(x)
plt.plot(x,y)

# %% [markdown]
# # Seaborn plot
# https://www.cnblogs.com/zxzhu/p/8675646.html

# %%
# import seaborn as sns
def sinplot(flip=1):
    x = np.linspace(0, 14, 100)
    for i in range(1, 7):
        plt.plot(x, np.sin(x + i * .5) * (7 - i) * flip)

sinplot()
